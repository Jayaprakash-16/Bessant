# %%
import pandas as pd
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

from pathlib import Path

# %%
print(pd.__version__)
# Out:
# 0.24.2

# %% [markdown]
# ### Check if your version is 0.25.0 some of the functionality may not work

# %%
data_folder = Path("occupancy_data")

# %%
! dir {data_folder}
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 5654-84E6
#
#  Directory of C:\Users\Jayaprakash\TutorialMaterial\occupancy_data
#
# 2019-10-18  09:43 AM    <DIR>          .
# 2019-10-18  09:43 AM    <DIR>          ..
# 2019-10-18  09:43 AM           604,825 datatraining.txt
#                1 File(s)        604,825 bytes
#                2 Dir(s)  884,406,452,224 bytes free

# %%
df = pd.read_csv(data_folder/"datatraining.txt",index_col = 1,parse_dates=True)

# %%
df.drop("index",inplace=True,axis=1)

# %%
df.head()
# Out:
#                      Temperature  Humidity  Light     CO2  HumidityRatio  \
# date"
# 2015-02-04 17:51:00        23.18   27.2720  426.0  721.25       0.004793
# 2015-02-04 17:51:59        23.15   27.2675  429.5  714.00       0.004783
# 2015-02-04 17:53:00        23.15   27.2450  426.0  713.50       0.004779
# 2015-02-04 17:54:00        23.15   27.2000  426.0  708.25       0.004772
# 2015-02-04 17:55:00        23.10   27.2000  426.0  704.50       0.004757
#
#                      Occupancy
# date"
# 2015-02-04 17:51:00          1
# 2015-02-04 17:51:59          1
# 2015-02-04 17:53:00          1
# 2015-02-04 17:54:00          1
# 2015-02-04 17:55:00          1

# %%
df.index # Observe the type of the index it is DatetimeIndex type
# Out:
# DatetimeIndex(['2015-02-04 17:51:00', '2015-02-04 17:51:59',
#                '2015-02-04 17:53:00', '2015-02-04 17:54:00',
#                '2015-02-04 17:55:00', '2015-02-04 17:55:59',
#                '2015-02-04 17:57:00', '2015-02-04 17:57:59',
#                '2015-02-04 17:58:59', '2015-02-04 18:00:00',
#                ...
#                '2015-02-10 09:23:59', '2015-02-10 09:24:59',
#                '2015-02-10 09:26:00', '2015-02-10 09:27:00',
#                '2015-02-10 09:28:00', '2015-02-10 09:29:00',
#                '2015-02-10 09:29:59', '2015-02-10 09:30:59',
#                '2015-02-10 09:32:00', '2015-02-10 09:33:00'],
#               dtype='datetime64[ns]', name='date"', length=8143, freq=None)

# %%
print(df.index.year)  # Get the year
print(df.index.month) # Get the month
print(df.index.day)   # Get the day
print(df.index.weekday_name) # Get the weekday name
# Out:
# Int64Index([2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015,
#             ...
#             2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015],
#            dtype='int64', name='date"', length=8143)
# Int64Index([2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#             ...
#             2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
#            dtype='int64', name='date"', length=8143)
# Int64Index([ 4,  4,  4,  4,  4,  4,  4,  4,  4,  4,
#             ...
#             10, 10, 10, 10, 10, 10, 10, 10, 10, 10],
# 2015-02-10 09:24:59          1
# 2015-02-10 09:26:00          1
# 2015-02-10 09:27:00          1
# 2015-02-10 09:28:00          1
# 2015-02-10 09:29:00          1
# 2015-02-10 09:29:59          1
# 2015-02-10 09:30:59          1
# 2015-02-10 09:32:00          1
# 2015-02-10 09:33:00          1
#
# [7774 rows x 6 columns]

# %%
# Lets see how the Co2 changes with time for whole data
df['CO2'].plot()

# %%
# plot only for a day
df.loc['2015-02-6']['CO2'].plot()

# %%
# Lets add the weekday name to data frame and see the trend day wise
df['WeekdayName'] = df.index.weekday_name

# %%
sns.boxplot(data=df, x='WeekdayName', y='CO2');

# %%
daily_mean = df['CO2'].resample('D').mean()

# %%
ax = daily_mean['2015-02'].plot()
df.loc['2015-02-05':"2015-02-10"]['CO2'].plot(ax = ax)

# %% [markdown]
# ### Rolling mean can be used to identify the trends in the data

# %%
df_1d = df.rolling(60*12).mean() # Average data for every 12 hours
df_2d = df.rolling(60*6).mean() # every hour
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\window.py in _prep_values(self, values, kill_inf)
#     210             try:
# --> 211                 values = ensure_float64(values)
#     212             except (ValueError, TypeError):
#
# pandas/_libs/algos_common_helper.pxi in pandas._libs.algos.ensure_float64()
#
# ValueError: could not convert string to float: 'Wednesday'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-f2d0e4ddb04c> in <module>
# ----> 1 df_1d = df.rolling(60*12).mean() # Average data for every 12 hours
#       2 df_2d = df.rolling(60*6).mean() # every hour
#
# ~\Anaconda3\lib\site-packages\pandas\core\window.py in mean(self, *args, **kwargs)
#    1726     def mean(self, *args, **kwargs):
#    1727         nv.validate_rolling_func('mean', args, kwargs)
# -> 1728         return super(Rolling, self).mean(*args, **kwargs)
#    1729
#    1730     @Substitution(name='rolling')
#
# ~\Anaconda3\lib\site-packages\pandas\core\window.py in mean(self, *args, **kwargs)
#    1070     def mean(self, *args, **kwargs):
#    1071         nv.validate_window_func('mean', args, kwargs)
# -> 1072         return self._apply('roll_mean', 'mean', **kwargs)
#    1073
#    1074     _shared_docs['median'] = dedent("""
#
# ~\Anaconda3\lib\site-packages\pandas\core\window.py in _apply(self, func, name, window, center, check_minp, **kwargs)
#     839         results = []
#     840         for b in blocks:
# --> 841             values = self._prep_values(b.values)
#     842
#     843             if values.size == 0:
#
# ~\Anaconda3\lib\site-packages\pandas\core\window.py in _prep_values(self, values, kill_inf)
#     212             except (ValueError, TypeError):
#     213                 raise TypeError("cannot handle this type -> {0}"
# --> 214                                 "".format(values.dtype))
#     215
#     216         if kill_inf:
#
# TypeError: cannot handle this type -> object

# %%
df_1d.head()
# Out:
#                      Temperature  Humidity  Light  CO2  HumidityRatio  \
# date"
# 2015-02-04 17:51:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-04 17:51:59          NaN       NaN    NaN  NaN            NaN
# 2015-02-04 17:53:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-04 17:54:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-04 17:55:00          NaN       NaN    NaN  NaN            NaN
#
#                      Occupancy
# date"
# 2015-02-04 17:51:00        NaN
# 2015-02-04 17:51:59        NaN
# 2015-02-04 17:53:00        NaN
# 2015-02-04 17:54:00        NaN
# 2015-02-04 17:55:00        NaN

# %%
ax = df_1d['CO2'].plot(marker='o',markevery=100)
df['CO2'].plot(ax=ax,marker='.')
df['CO2'].plot(ax=ax)

# %% [markdown]
# ## One of the best resources https://jakevdp.github.io/PythonDataScienceHandbook/03.11-working-with-time-series.html
